# %%
import time
import pandas as pd
from newspaper import Article
from konlpy.tag import Okt
from collections import Counter
from collections import OrderedDict
from selenium import webdriver
from selenium.webdriver.common.by import By

df = pd.DataFrame()
totalDataList = list()

keyword = str(input("수집할 키워드를 입력하세요 : "))
input_page_number = int(input("수집할 페이지 개수를 입력하세요 : "))
href_count = 1

driver = webdriver.Chrome()
driver.maximize_window()
time.sleep(1)

driver.get("https://www.naver.com/")
driver.find_element(By.XPATH, '//*[@id="query"]').send_keys(keyword)
time.sleep(1)

driver.find_element(By.XPATH, '//*[@id="search_btn"]/span[2]').click()
time.sleep(1)

driver.find_element(By.LINK_TEXT, '뉴스').click()

for page in range(1, input_page_number+1):
    page_xpath = f'//*[@id="main_pack"]/div[2]/div/div/a[{page}]'
    driver.find_element(By.XPATH, page_xpath).click()
    time.sleep(2)

    news_title = driver.find_elements(By.CSS_SELECTOR, 'a.news_tit')

    for i in news_title:
        news_href_ = i.get_attribute("href")

        article = Article(news_href_, language='ko')

        try:
            article.download()
            article.parse()
        except:
            continue

        pan_title = article.title
        pan_content = article.text.strip().replace("\n", "")
        if pan_content is None:
            continue

        engine = Okt()
        all_nouns = engine.nouns(pan_content)
        nouns = [n for n in all_nouns if len(n) > 1]

        count = Counter(nouns)
        by_num = OrderedDict(sorted(count.items(), key=lambda t: t[1], reverse=True))

        word_5 = ",".join(list(by_num)[:5])

        dataList = [str(pan_title), str(pan_content), str(news_href_), str(word_5)]
        totalDataList.append(dataList)
        print(f"{href_count}번 째 데이터 수집 및 처리 완료")
        href_count += 1

df = pd.DataFrame(totalDataList, columns=["제목", "내용", "기사 URL", "단어 5가지"])
df.to_csv("selenium_naver_news.csv", encoding="utf-8-sig", index=False)
print("all working's complete.")
driver.close()
# Out:
# 1번 째 데이터 수집 및 처리 완료
# 2번 째 데이터 수집 및 처리 완료
# 3번 째 데이터 수집 및 처리 완료
# 4번 째 데이터 수집 및 처리 완료
# 5번 째 데이터 수집 및 처리 완료
# 6번 째 데이터 수집 및 처리 완료
# 7번 째 데이터 수집 및 처리 완료
# 8번 째 데이터 수집 및 처리 완료
# 9번 째 데이터 수집 및 처리 완료
# 10번 째 데이터 수집 및 처리 완료
# 11번 째 데이터 수집 및 처리 완료
# 12번 째 데이터 수집 및 처리 완료
# 13번 째 데이터 수집 및 처리 완료
# 14번 째 데이터 수집 및 처리 완료
# 15번 째 데이터 수집 및 처리 완료
# 16번 째 데이터 수집 및 처리 완료
# 17번 째 데이터 수집 및 처리 완료
# 18번 째 데이터 수집 및 처리 완료
# 19번 째 데이터 수집 및 처리 완료
# 20번 째 데이터 수집 및 처리 완료
# 21번 째 데이터 수집 및 처리 완료
# 22번 째 데이터 수집 및 처리 완료
# 23번 째 데이터 수집 및 처리 완료
# 24번 째 데이터 수집 및 처리 완료
# 25번 째 데이터 수집 및 처리 완료
# 26번 째 데이터 수집 및 처리 완료
# 27번 째 데이터 수집 및 처리 완료
# 28번 째 데이터 수집 및 처리 완료
# 29번 째 데이터 수집 및 처리 완료
# 30번 째 데이터 수집 및 처리 완료
# 31번 째 데이터 수집 및 처리 완료
# 32번 째 데이터 수집 및 처리 완료
# 33번 째 데이터 수집 및 처리 완료
# 34번 째 데이터 수집 및 처리 완료
# 35번 째 데이터 수집 및 처리 완료
# 36번 째 데이터 수집 및 처리 완료
# 37번 째 데이터 수집 및 처리 완료
# 38번 째 데이터 수집 및 처리 완료
# 39번 째 데이터 수집 및 처리 완료
# 40번 째 데이터 수집 및 처리 완료
# 41번 째 데이터 수집 및 처리 완료
# 42번 째 데이터 수집 및 처리 완료
# 43번 째 데이터 수집 및 처리 완료
# 44번 째 데이터 수집 및 처리 완료
# 45번 째 데이터 수집 및 처리 완료
# all working's complete.
